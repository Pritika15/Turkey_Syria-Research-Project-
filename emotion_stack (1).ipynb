# %%
# !gdown 1546uW37C7YI8YPR6-SVCESH3fdKbTe5Z&export=download
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1546uW37C7YI8YPR6-SVCESH3fdKbTe5Z
# To: /content/StackingClassifier.csv
# 100% 105M/105M [00:02<00:00, 47.0MB/s]

# %%
import pandas as pd

# %%
df=pd.read_csv('StackingClassifier.csv')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 text sentiment  \
# 0  member medical team dispatched agra based army...   neutral
# 1  earthquake relief turkey aerial recovery looki...   neutral
# 2  mozaik foundation launched emergency relief fu...   neutral
# 3  call contribute earthquake relief come people ...  positive
# 4  compliance royal order sultan haitham bin tari...   neutral
#
#   textblob_sentiment vader_sentiment flair_sentiment  textblob_sentiment_num  \
# 0            neutral        positive        positive                       0
# 1            neutral        positive        positive                       0
# 2            neutral        positive        negative                       0
# 3           positive        positive        negative                       1
# ...

# %%
# !pip install wordnet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wordnet: filename=wordnet-0.0.1b2-py3-none-any.whl size=10521 sha256=191f94fec60b4c156564b1ecd2b1125eb1c45eeeabf7c99883d6fd3f91f66373
#   Stored in directory: /root/.cache/pip/wheels/01/be/ef/2424637bbd3690b10b7fc1c16faa12fdd053ff6b1abb2c3c08
# Successfully built wordnet
# ...

# %%
df['text'].iloc[0]
sf=df['text'].iloc[0].split()

# %%
sf
# Out:
# ['member',
#  'medical',
#  'team',
#  'dispatched',
#  'agra',
#  'based',
#  'army',
#  'field',
#  'hospital',
#  'turkey',
#  'two',
#  'c',
#  'plane',
#  'turkey',
#  'evening',
#  'para',
#  'field',
#  'hospital',
#  'personnel',
#  'aid',
#  'rescue',
#  'relief',
#  'operation']

# %%
def func(label,text):
  sf1=text.split()
  conf=[0.0]*len(label) #list for confidence score of each label
  # print(sf1) 
  for i in range(len(label)):
    value1=[]
    for j in sf1:
      syn1 = wordnet.synsets(label[i])[0]
      syn2 = wordnet.synsets(j)
      if(not syn2):
        continue
      value=syn1.wup_similarity(syn2[0])
      conf[i]+=value
  print(conf)
  return label[conf.index(max(conf))]

# %%
from nltk.corpus import wordnet
label=['happy','anger','fear','surprise','unemotional','sympathy','sad','relief','disgust','enthusiasm','joy']

# # for textData in df['text']:
# for i in 
# syn1 = wordnet.synsets(sf[0])[0]
# syn2 = wordnet.synsets('happy')[0]
# syn1.wup_similarity(syn2)

val=func(label,df['text'].iloc[53873])
print(val)
# Out:
# ['earthquake', 'disaster', 'syria', 'united', 'state', 'snatched', 'syrian', 'wheat', 'deliberately', 'created', 'hegemonic', 'humanitarian', 'disaster', 'china', 'sent', 'wheat']
# [3.551631701631701, 3.012350394703336, 3.012350394703336, 3.012350394703336, 3.551631701631701, 2.512350394703336, 3.551631701631701, 2.8130240674358324, 3.012350394703336, 3.2435654988286564, 3.012350394703336]
# happy

# %%
df['text'].iloc[0]
# Out:
# 'member medical team dispatched agra based army field hospital turkey two c plane turkey evening para field hospital personnel aid rescue relief operation'

# %%
df['text']
# Out:
# 0         member medical team dispatched agra based army...
# 1         earthquake relief turkey aerial recovery looki...
# 2         mozaik foundation launched emergency relief fu...
# 3         call contribute earthquake relief come people ...
# 4         compliance royal order sultan haitham bin tari...
#                                 ...
# 678714    according biblical prophecy earthquake sign co...
# 678715                 earthquake causing shift train track
# 678716          story tell kp citizen let meet washroom r r
# 678717        earthquake stefano carparelli next generation
# 678718    earth horrid jaw half open show plaint innocen...
# Name: text, Length: 678719, dtype: object

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
df['emotion_label'] = df['text'].map(lambda row: func(label,row))
# Out:
# Streaming output truncated to the last 5000 lines.
# [3.382936507936508, 2.8433566433566435, 2.8433566433566435, 2.8433566433566435, 3.382936507936508, 2.390975690975691, 3.382936507936508, 2.630802530802531, 2.8433566433566435, 3.094307446939026, 2.8433566433566435]
# [3.9112859362859367, 3.9439315586374404, 3.9439315586374404, 3.9439315586374404, 3.9112859362859367, 4.131606628665452, 3.9112859362859367, 3.669798502151443, 3.9439315586374404, 4.263549316180895, 3.9439315586374404]
# [1.6194444444444445, 1.4764152514152513, 1.4764152514152513, 1.4764152514152513, 1.6194444444444445, 1.4764152514152513, 1.6194444444444445, 1.3729584141348847, 1.4764152514152513, 1.5971046497362287, 1.4764152514152513]
# [1.3275252525252523, 2.008241758241758, 2.008241758241758, 2.008241758241758, 1.3275252525252523, 1.5338827838827838, 1.3275252525252523, 1.8718325791855204, 2.008241758241758, 2.166468619100198, 2.008241758241758]
# ...
